# %% [markdown]
# <a href="https://colab.research.google.com/github/Dheerajnath/NLP_LAB_EXPERIMENTS/blob/main/NLP_EXPT_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4976471a-a252-4793-ba17-e71965ea78ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4976471a-a252-4793-ba17-e71965ea78ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('twitter4000.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   twitts     4000 non-null   object
#  1   sentiment  4000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 62.6+ KB

# %%
data.count()
# Out:
# twitts       4000
# sentiment    4000
# dtype: int64

# %%
data['sentiment'].value_counts()
# Out:
# sentiment
# 0    2000
# 1    2000
# Name: count, dtype: int64

# %%
data.head()
# Out:
#                                               twitts  sentiment
# 0  is bored and wants to watch a movie  any sugge...          0
# 1           back in miami.  waiting to unboard ship           0
# 2  @misskpey awwww dnt dis brng bak memoriessss, ...          0
# 3                  ughhh i am so tired  blahhhhhhhhh          0
# 4  @mandagoforth me bad! It's funny though. Zacha...          0

# %%
pattern = r'\s'
data['twitts'].apply(lambda x: re.sub(pattern, '', x))
# Out:
# 0             isboredandwantstowatchamovieanysuggestions?
# 1                        backinmiami.waitingtounboardship
# 2       @misskpeyawwwwdntdisbrngbakmemoriessss,IthnkI'...
# 3                             ughhhiamsotiredblahhhhhhhhh
# 4       @mandagoforthmebad!It'sfunnythough.ZacharyQuin...
#                               ...
# 3995                                       ijustgraduated
# 3996                     Templatingworks;itallhastobedone
# 3997                          mommyjustbroughtmestarbucks
# 3998        @omareppswatchingyouonaHousere-run...lovinit.
# 3999    ThanksfortryingtomakemesmileI'llmakeyour18thsp...
# Name: twitts, Length: 4000, dtype: object

# %%
pattern = r'\s'
data['char_count']=data['twitts'].apply(lambda x: len(re.sub(pattern, '', x)))
data
# Out:
#                                                  twitts  sentiment  char_count
# 0     is bored and wants to watch a movie  any sugge...          0          43
# 1              back in miami.  waiting to unboard ship           0          32
# 2     @misskpey awwww dnt dis brng bak memoriessss, ...          0          54
# 3                     ughhh i am so tired  blahhhhhhhhh          0          27
# 4     @mandagoforth me bad! It's funny though. Zacha...          0         116
# ...                                                 ...        ...         ...
# 3995                                  i just graduated           1          14
# 3996          Templating works; it all has to be done            1          32
# 3997                   mommy just brought me starbucks           1          27
# 3998  @omarepps watching you on a House re-run...lov...          1          45
# 3999  Thanks for trying to make me smile I'll make y...          1          63
#
# [4000 rows x 3 columns]

# %%
pattern = r'[!"#$%&\'()*+,-./:;<=>?@[\]^_`{|}~]'
data['twitts'] = data['twitts'].apply(lambda x: re.sub(pattern, '', x))
data
# Out:
#                                                  twitts  sentiment  \
# 0            isboredandwantstowatchamovieanysuggestions          0
# 1                       backinmiamiwaitingtounboardship          0
# 2     misskpeyawwwwdntdisbrngbakmemoriessssIthnkImsa...          0
# 3                           ughhhiamsotiredblahhhhhhhhh          0
# 4     mandagoforthmebadItsfunnythoughZacharyQuintois...          0
# ...                                                 ...        ...
# 3995                                     ijustgraduated          1
# 3996                    Templatingworksitallhastobedone          1
# 3997                        mommyjustbroughtmestarbucks          1
# 3998            omareppswatchingyouonaHousererunlovinit          1
# 3999  ThanksfortryingtomakemesmileIllmakeyour18thspe...          1
#
#       char_count  hash_tags_count  mentions
# 0             43                0         0
# 1             32                0         0
# ...

# %%
data['hash_tags_count']= data['twitts'].apply(lambda x: len(re.findall(r'#(\w+)', x)))
data.sample(4)
# Out:
#                                                  twitts  sentiment  \
# 382                                     Lifeisconfusing          0
# 3040                   @MrSkidmoreGoodjobtonightdude...          1
# 355   1stdaybacktosklItsveryhotevenmythintightsfeelu...          0
# 3547   @kattwilkieThankyouKathybbz!Itfeelsbetteralready          1
#
#       char_count  hash_tags_count
# 382           15                0
# 3040          32                0
# 355           55                0
# 3547          48                0

# %%
data['mentions']= data['twitts'].apply(lambda x: len(re.findall(r'#(\w+)', x)))
data.sample(10)
# Out:
#                                                  twitts  sentiment  \
# 3305  @TalktoDianeHiDiane.Thenewsiteandblogswilllaun...          1
# 2618  @iwantyourjeepwhat'stheprob?gettingsleepy-shou...          1
# 3575  @kirstiealley:Ooopsthatshouldhavebeen@GrahamNo...          1
# 2970     @lilxicanitaawwmecheeeyoucanbemyfriend...lol..          1
# 2281  shameicanhearmyparentstalkingaboutme*smirks*an...          1
# 2248  OHyayforgottocomebackNowiwatchedtodaythreemovi...          1
# 3676                               Tonightwasagoodnight          1
# 2454   isimpatientlywaitingforherlittlesistertogethere!          1
# 95                              Ifonlytheyunderstood...          0
# 724   Oki'lltrytouploadmypic...hopeitworks,ifnotinee...          0
#
#       char_count  hash_tags_count  mentions
# 3305         112                0         0
# 2618          76                0         0
# 3575          77                0         0
# 2970          46                0         0
# ...

# %%
data['twitts'].apply(lambda x: len([word for word in x.split()if word.isupper()]))
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3995    0
# 3996    0
# 3997    0
# 3998    0
# 3999    0
# Name: twitts, Length: 4000, dtype: int64
